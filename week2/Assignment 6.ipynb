# %%
import pandas as pd
import seaborn as sns

# %%
covid = pd.read_csv('covid/covid_19_data.csv')

# %%
covid.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
covid = covid[covid['Province/State'] == 'Zeeland']
covid.head()
# Out:
#          SNo ObservationDate Province/State Country/Region  \
# 66457  66458      07/17/2020        Zeeland    Netherlands
# 67200  67201      07/18/2020        Zeeland    Netherlands
# 67943  67944      07/19/2020        Zeeland    Netherlands
# 68686  68687      07/20/2020        Zeeland    Netherlands
# 69429  69430      07/21/2020        Zeeland    Netherlands
#
#                Last Update  Confirmed  Deaths  Recovered
# 66457  2020-07-18 04:34:45      771.0    69.0        0.0
# 67200  2020-07-19 04:34:58      785.0    69.0        0.0
# 67943  2020-07-20 05:34:40      791.0    69.0        0.0
# 68686  2020-07-21 04:38:46      791.0    69.0        0.0
# 69429  2020-07-22 04:34:42      800.0    69.0        0.0

# %%
covid['Confirmed'].plot().set_ylabel('Confirmed')
# Out:
# Text(0, 0.5, 'Confirmed')

# %%
covid['Deaths'].plot().set_ylabel('Deaths')
# Out:
# Text(0, 0.5, 'Deaths')

# %%
covidDeaths = pd.read_csv('covid/time_series_covid_19_deaths.csv')
covidDeaths.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  1/10/21  1/11/21  1/12/21  \
# 0        0        0        0        0  ...     2277     2288     2301
# 1        0        0        0        0  ...     1241     1247     1252
# 2        0        0        0        0  ...     2807     2812     2816
# 3        0        0        0        0  ...       85       85       86
# 4        0        0        0        0  ...      416      420      422
#
#    1/13/21  1/14/21  1/15/21  1/16/21  1/17/21  1/18/21  1/19/21
# ...

# %%
covidDeaths = covidDeaths[covidDeaths['Country/Region'] == 'Netherlands']
covidDeaths
# Out:
#                        Province/State Country/Region      Lat     Long  \
# 190                             Aruba    Netherlands  12.5211 -69.9683
# 191  Bonaire, Sint Eustatius and Saba    Netherlands  12.1784 -68.2385
# 192                           Curacao    Netherlands  12.1696 -68.9900
# 193                      Sint Maarten    Netherlands  18.0425 -63.0548
# 194                               NaN    Netherlands  52.1326   5.2913
#
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  1/10/21  \
# 190        0        0        0        0        0        0  ...       51
# 191        0        0        0        0        0        0  ...        3
# 192        0        0        0        0        0        0  ...       19
# 193        0        0        0        0        0        0  ...       27
# 194        0        0        0        0        0        0  ...    12361
#
#      1/11/21  1/12/21  1/13/21  1/14/21  1/15/21  1/16/21  1/17/21  1/18/21  \
# ...
